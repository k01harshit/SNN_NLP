# %%
# ==============================================================================
# NLP-SNN BENCHMARKING RUNNER (v6.0 - Advanced Encoders)
# ==============================================================================

# %run nlp_snn_funs106.py
import sys
import subprocess
import os
import traceback
import warnings

# Suppress minor TF warnings for cleaner output
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.filterwarnings('ignore')

# 1. CRITICAL DEPENDENCY CHECK
try:
    import tensorflow_text
    print("[System] tensorflow_text is already installed.")
except ImportError:
    print("[System] tensorflow_text not found. Installing now...")
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "tensorflow-text"])
        import tensorflow_text
        print("[System] Successfully installed tensorflow_text.")
    except Exception as e:
        print(f"[System] WARNING: Automatic installation failed ({e}).")
        print("          Some models (BERT, USE, mmBERT) may fail.")

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 2. IMPORT BENCHMARKING FUNCTIONS
try:
    from nlp_snn_funs106 import train_benchmark
except ImportError:
    print("\n[CRITICAL ERROR] Could not import 'nlp_snn_benchmarking_functions_50.py'.")
    print("Please ensure the functions file is uploaded and in the same directory.")
    sys.exit(1)

# ==============================================================================
# CONFIGURATION
# ==============================================================================

datasets = ['imdb', 'ag_news', 'sst2', 'yelp']

# FULL ENCODER SUITE (Updated with Advanced Transformers)
encoders = [
    'DAN',          # Baseline: Deep Averaging Network
    'CNN',          # Baseline: 1D Convolution
    'Transformer',  # Baseline: Custom Attention
    'Word2Vec',     # Static: NNLM-128
    'USE',          # Transfer: Universal Sentence Encoder
    'BERT',         # Advanced: Official BERT-Base
    'RoBERTa',      # Advanced: Robustly Optimized BERT
    'NeoBERT',      # Advanced: Electra (Generator-Discriminator)
    'mmBERT'        # Advanced: Multi-lingual BERT
]

# SNN CONFIGURATION
SNN_EPOCHS = 25  # Increased to 25 as requested

# ==============================================================================
# MAIN EXECUTION LOOP
# ==============================================================================

def main():
    all_metrics = []

    print("############################################################")
    print("STARTING NLP-SNN BENCHMARK (v6.0)")
    print(f"Datasets ({len(datasets)}): {datasets}")
    print(f"Encoders ({len(encoders)}): {encoders}")
    print(f"SNN Scheme: 1-SADP (25 Epochs)")
    print("############################################################")

    for data_name in datasets:
        for enc_name in encoders:
            try:
                print(f"\n>>> RUNNING: Dataset={data_name.upper()} | Encoder={enc_name} <<<")

                # Execute the pipeline
                logs = train_benchmark(data_name, enc_name, snn_epochs=SNN_EPOCHS)

                # Aggregate results
                for log in logs:
                    all_metrics.append(log)

            except KeyboardInterrupt:
                print("\n[System] Benchmark interrupted by user. Saving current progress...")
                save_and_plot(all_metrics)
                sys.exit(0)
            except Exception as e:
                print(f"!!! CRITICAL FAILURE on {data_name}-{enc_name}: {type(e).__name__}: {e}")

    # Final Report
    save_and_plot(all_metrics)

# ==============================================================================
# ANALYSIS & VISUALIZATION HELPERS
# ==============================================================================

def save_and_plot(metrics_list):
    if not metrics_list:
        print("\n[System] No results to save.")
        return

    # 1. Convert to DataFrame
    df = pd.DataFrame(metrics_list)
    output_csv = "nlp_snn_benchmark_results_v6.csv"
    df.to_csv(output_csv, index=False)
    print(f"\n[System] Benchmark Complete. Raw data saved to {output_csv}")

    # 2. Detailed Tabular Report
    print("\n" + "="*100)
    print("FINAL BENCHMARK REPORT (Metrics at Final Epoch)")
    print("="*100)

    # Filter for the last epoch of each run
    final_df = df[df['epoch'] == df['epoch'].max()].copy()

    # Select and Rename columns for clarity
    display_cols = [
        'dataset', 'encoder', 'train_acc',
        'time_epoch', 'energy_sample_j',
        'enc_time', 'feat_time'
    ]

    final_table = final_df[display_cols].rename(columns={
        'dataset': 'Dataset',
        'encoder': 'Encoder',
        'train_acc': 'Accuracy',
        'time_epoch': 'SNN Epoch(s)',
        'energy_sample_j': 'Energy (J)',
        'enc_time': 'ANN Train(s)',
        'feat_time': 'Extract(s)'
    })

    # Sort by Dataset then Accuracy (Descending)
    final_table = final_table.sort_values(by=['Dataset', 'Accuracy'], ascending=[True, False])

    # Print formatted table
    print(final_table.to_string(index=False, formatters={
        'Accuracy': '{:.4f}'.format,
        'SNN Epoch(s)': '{:.2f}'.format,
        'Energy (J)': '{:.2e}'.format,
        'ANN Train(s)': '{:.2f}'.format,
        'Extract(s)': '{:.2f}'.format
    }))
    print("="*100)

    # 3. Generate Plots
    try:
        sns.set_theme(style="whitegrid")

        # Plot A: Accuracy Evolution (Line Plot)
        plt.figure(figsize=(14, 8))
        sns.lineplot(
            data=df,
            x='epoch',
            y='train_acc',
            hue='encoder',
            style='dataset',
            markers=True,
            dashes=False,
            linewidth=2
        )
        plt.title(f"SNN (1-SADP) Accuracy Evolution over {df['epoch'].max()} Epochs")
        plt.ylabel("Accuracy")
        plt.xlabel("Epoch")
        plt.ylim(0.4, 1.0) # Focus on the upper half of accuracy
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title="Encoder")
        plt.tight_layout()
        plt.savefig("snn_accuracy_evolution.png", dpi=300)
        print("[System] Saved plot: snn_accuracy_evolution.png")

        # Plot B: Energy Efficiency (Bar Plot)
        if not final_df.empty:
            plt.figure(figsize=(12, 6))
            sns.barplot(
                data=final_df,
                x='encoder',
                y='energy_sample_j',
                hue='dataset',
                palette='viridis'
            )
            plt.title("Estimated On-Chip Dynamic Energy (Joules per Batch)")
            plt.ylabel("Energy (Joules) - Log Scale")
            plt.xlabel("Encoder Architecture")
            plt.yscale('log') # Log scale is vital for energy comparisons
            plt.legend(title="Dataset")
            plt.tight_layout()
            plt.savefig("snn_energy_efficiency.png", dpi=300)
            print("[System] Saved plot: snn_energy_efficiency.png")

    except Exception as e:
        print(f"[System] Error generating plots: {e}")

if __name__ == "__main__":
    main()
# Out:
# [19:02:30] [System] tensorflow_text imported successfully.
# [System] tensorflow_text is already installed.
# [19:02:30] [System] tensorflow_text imported successfully.
# ############################################################
# STARTING NLP-SNN BENCHMARK (v6.0)
# Datasets (4): ['imdb', 'ag_news', 'sst2', 'yelp']
# Encoders (9): ['DAN', 'CNN', 'Transformer', 'Word2Vec', 'USE', 'BERT', 'RoBERTa', 'NeoBERT', 'mmBERT']
# SNN Scheme: 1-SADP (25 Epochs)
# ############################################################
#
# >>> RUNNING: Dataset=IMDB | Encoder=DAN <<<
# [2026-02-06 19:02:30] ==================================================================
# [2026-02-06 19:02:30] STARTING PIPELINE: Dataset=imdb | Encoder=DAN
# [2026-02-06 19:02:30] ==================================================================
# [2026-02-06 19:02:30] [Data] Initiating load for dataset: IMDB...
# [2026-02-06 19:02:30] [Data] Downloading/Loading TFDS: imdb_reviews...
# WARNING:absl:Variant folder /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.S9CF14_1.0.0/imdb_reviews-train.tfrecor…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.S9CF14_1.0.0/imdb_reviews-test.tfrecord…
# Generating unsupervised examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.S9CF14_1.0.0/imdb_reviews-unsupervised.…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# [2026-02-06 19:03:14] [Data] Extracting... (Train Limit: 10000, Test Limit: 10000)
# [2026-02-06 19:03:23] [Data] Loaded 10000 train, 10000 test samples.
# [2026-02-06 19:03:23] [Encoder] Constructing architecture: DAN
# [2026-02-06 19:03:23] [Encoder] Model Built. Feature Output Shape: (None, 256)
# [2026-02-06 19:03:23] [Encoder] Starting ANN Pre-training (1 Epoch)...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6367 - loss: 0.6076
# [2026-02-06 19:03:34] [Encoder] ANN Training Complete. Time: 11.48s | Final Acc: 0.7261
# [2026-02-06 19:03:34] [Features] Generating Static Embeddings for SNN...
# [2026-02-06 19:03:37] [Features] Extraction Complete. Time: 2.42s
# [2026-02-06 19:03:37] [Features] Embedding Shape: (10000, 256)
# [2026-02-06 19:03:37] [SNN] Info: Running 1-SADP (Single Layer Supervised Plasticity)
# [2026-02-06 19:03:37] [SNN] Init 1-SADP Architecture. W1(Fixed):(256, 256), W2(Trainable):(256, 2)
# [2026-02-06 19:03:37] [SNN] Starting SNN Training Loop (25 Epochs)...
# [2026-02-06 19:03:40]   [Epoch 1/25] Acc: 0.7574 | Time: 2.89s | Energy (Sample): 3.51e-08 J
# [2026-02-06 19:03:45]   [Epoch 2/25] Acc: 0.8559 | Time: 5.14s | Energy (Sample): 3.90e-08 J
# [2026-02-06 19:03:48]   [Epoch 3/25] Acc: 0.8677 | Time: 2.85s | Energy (Sample): 4.35e-08 J
# [2026-02-06 19:03:51]   [Epoch 4/25] Acc: 0.8770 | Time: 2.85s | Energy (Sample): 4.39e-08 J
# [2026-02-06 19:03:54]   [Epoch 5/25] Acc: 0.8764 | Time: 2.81s | Energy (Sample): 4.42e-08 J
# [2026-02-06 19:04:00]   [Epoch 6/25] Acc: 0.8752 | Time: 5.72s | Energy (Sample): 4.16e-08 J
# [2026-02-06 19:04:03]   [Epoch 7/25] Acc: 0.8731 | Time: 2.97s | Energy (Sample): 4.49e-08 J
# [2026-02-06 19:04:06]   [Epoch 8/25] Acc: 0.8781 | Time: 2.83s | Energy (Sample): 4.29e-08 J
# [2026-02-06 19:04:11]   [Epoch 9/25] Acc: 0.8754 | Time: 5.01s | Energy (Sample): 4.60e-08 J
# [2026-02-06 19:04:14]   [Epoch 10/25] Acc: 0.8758 | Time: 2.88s | Energy (Sample): 4.68e-08 J
# [2026-02-06 19:04:17]   [Epoch 11/25] Acc: 0.8781 | Time: 2.83s | Energy (Sample): 4.48e-08 J
# [2026-02-06 19:04:20]   [Epoch 12/25] Acc: 0.8728 | Time: 2.79s | Energy (Sample): 4.41e-08 J
# [2026-02-06 19:04:25]   [Epoch 13/25] Acc: 0.8731 | Time: 5.01s | Energy (Sample): 4.54e-08 J
# [2026-02-06 19:04:28]   [Epoch 14/25] Acc: 0.8720 | Time: 2.78s | Energy (Sample): 4.68e-08 J
# [2026-02-06 19:04:31]   [Epoch 15/25] Acc: 0.8774 | Time: 2.92s | Energy (Sample): 4.59e-08 J
# [2026-02-06 19:04:34]   [Epoch 16/25] Acc: 0.8777 | Time: 2.82s | Energy (Sample): 4.54e-08 J
# [2026-02-06 19:04:39]   [Epoch 17/25] Acc: 0.8755 | Time: 5.27s | Energy (Sample): 4.64e-08 J
# [2026-02-06 19:04:42]   [Epoch 18/25] Acc: 0.8760 | Time: 2.74s | Energy (Sample): 4.78e-08 J
# [2026-02-06 19:04:45]   [Epoch 19/25] Acc: 0.8748 | Time: 2.78s | Energy (Sample): 4.73e-08 J
# [2026-02-06 19:04:48]   [Epoch 20/25] Acc: 0.8766 | Time: 2.76s | Energy (Sample): 4.86e-08 J
# [2026-02-06 19:04:53]   [Epoch 21/25] Acc: 0.8758 | Time: 5.01s | Energy (Sample): 4.55e-08 J
# [2026-02-06 19:04:56]   [Epoch 22/25] Acc: 0.8756 | Time: 2.72s | Energy (Sample): 4.43e-08 J
# [2026-02-06 19:04:59]   [Epoch 23/25] Acc: 0.8742 | Time: 2.77s | Energy (Sample): 5.06e-08 J
# [2026-02-06 19:05:02]   [Epoch 24/25] Acc: 0.8758 | Time: 2.78s | Energy (Sample): 4.77e-08 J
# [2026-02-06 19:05:07]   [Epoch 25/25] Acc: 0.8781 | Time: 5.03s | Energy (Sample): 4.69e-08 J
# [2026-02-06 19:05:07] [SNN] Training Complete.
#
# >>> RUNNING: Dataset=IMDB | Encoder=CNN <<<
# [2026-02-06 19:05:07] ==================================================================
# [2026-02-06 19:05:07] STARTING PIPELINE: Dataset=imdb | Encoder=CNN
# [2026-02-06 19:05:07] ==================================================================
# [2026-02-06 19:05:07] [Data] Initiating load for dataset: IMDB...
# [2026-02-06 19:05:07] [Data] Downloading/Loading TFDS: imdb_reviews...
# [2026-02-06 19:05:07] [Data] Extracting... (Train Limit: 10000, Test Limit: 10000)
# [2026-02-06 19:05:15] [Data] Loaded 10000 train, 10000 test samples.
# [2026-02-06 19:05:15] [Encoder] Constructing architecture: CNN
# [2026-02-06 19:05:15] [Encoder] Model Built. Feature Output Shape: (None, 256)
# [2026-02-06 19:05:15] [Encoder] Starting ANN Pre-training (1 Epoch)...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.6083 - loss: 0.6348
# [2026-02-06 19:05:34] [Encoder] ANN Training Complete. Time: 19.74s | Final Acc: 0.6977
# [2026-02-06 19:05:34] [Features] Generating Static Embeddings for SNN...
# [2026-02-06 19:05:44] [Features] Extraction Complete. Time: 9.68s
# [2026-02-06 19:05:44] [Features] Embedding Shape: (10000, 256)
# [2026-02-06 19:05:44] [SNN] Info: Running 1-SADP (Single Layer Supervised Plasticity)
# [2026-02-06 19:05:44] [SNN] Init 1-SADP Architecture. W1(Fixed):(256, 256), W2(Trainable):(256, 2)
# [2026-02-06 19:05:44] [SNN] Starting SNN Training Loop (25 Epochs)...
# [2026-02-06 19:05:47]   [Epoch 1/25] Acc: 0.4999 | Time: 2.78s | Energy (Sample): 1.89e-09 J
# [2026-02-06 19:05:50]   [Epoch 2/25] Acc: 0.6134 | Time: 2.81s | Energy (Sample): 2.98e-09 J
# [2026-02-06 19:05:53]   [Epoch 3/25] Acc: 0.7339 | Time: 2.71s | Energy (Sample): 2.87e-09 J
# [2026-02-06 19:05:58]   [Epoch 4/25] Acc: 0.7323 | Time: 4.71s | Energy (Sample): 3.03e-09 J
# [2026-02-06 19:06:01]   [Epoch 5/25] Acc: 0.7278 | Time: 2.79s | Energy (Sample): 3.07e-09 J
# [2026-02-06 19:06:03]   [Epoch 6/25] Acc: 0.6252 | Time: 2.71s | Energy (Sample): 4.13e-09 J
# [2026-02-06 19:06:07]   [Epoch 7/25] Acc: 0.5213 | Time: 3.05s | Energy (Sample): 4.07e-09 J
# [2026-02-06 19:06:11]   [Epoch 8/25] Acc: 0.5560 | Time: 4.46s | Energy (Sample): 4.36e-09 J
# [2026-02-06 19:06:14]   [Epoch 9/25] Acc: 0.5543 | Time: 2.70s | Energy (Sample): 4.14e-09 J
# [2026-02-06 19:06:17]   [Epoch 10/25] Acc: 0.5555 | Time: 2.76s | Energy (Sample): 4.64e-09 J
# [2026-02-06 19:06:22]   [Epoch 11/25] Acc: 0.5466 | Time: 4.33s | Energy (Sample): 4.13e-09 J
# [2026-02-06 19:06:25]   [Epoch 12/25] Acc: 0.5554 | Time: 3.13s | Energy (Sample): 4.75e-09 J
# [2026-02-06 19:06:28]   [Epoch 13/25] Acc: 0.5507 | Time: 2.79s | Energy (Sample): 4.78e-09 J
# [2026-02-06 19:06:31]   [Epoch 14/25] Acc: 0.5538 | Time: 2.75s | Energy (Sample): 4.79e-09 J
# [2026-02-06 19:06:35]   [Epoch 15/25] Acc: 0.5521 | Time: 4.75s | Energy (Sample): 5.10e-09 J
# [2026-02-06 19:06:38]   [Epoch 16/25] Acc: 0.5581 | Time: 2.78s | Energy (Sample): 4.83e-09 J
# [2026-02-06 19:06:41]   [Epoch 17/25] Acc: 0.5593 | Time: 2.81s | Energy (Sample): 4.89e-09 J
# [2026-02-06 19:06:44]   [Epoch 18/25] Acc: 0.5556 | Time: 2.77s | Energy (Sample): 5.12e-09 J
# [2026-02-06 19:06:49]   [Epoch 19/25] Acc: 0.5591 | Time: 4.80s | Energy (Sample): 4.82e-09 J
# [2026-02-06 19:06:52]   [Epoch 20/25] Acc: 0.5576 | Time: 2.73s | Energy (Sample): 5.12e-09 J
# [2026-02-06 19:06:55]   [Epoch 21/25] Acc: 0.5548 | Time: 2.74s | Energy (Sample): 5.18e-09 J
# [2026-02-06 19:06:58]   [Epoch 22/25] Acc: 0.5571 | Time: 2.74s | Energy (Sample): 4.98e-09 J
# [2026-02-06 19:07:02]   [Epoch 23/25] Acc: 0.5588 | Time: 4.78s | Energy (Sample): 4.60e-09 J
# [2026-02-06 19:07:05]   [Epoch 24/25] Acc: 0.5547 | Time: 2.79s | Energy (Sample): 4.59e-09 J
# [2026-02-06 19:07:08]   [Epoch 25/25] Acc: 0.5571 | Time: 2.70s | Energy (Sample): 5.21e-09 J
# [2026-02-06 19:07:08] [SNN] Training Complete.
#
# >>> RUNNING: Dataset=IMDB | Encoder=Transformer <<<
# [2026-02-06 19:07:08] ==================================================================
# [2026-02-06 19:07:08] STARTING PIPELINE: Dataset=imdb | Encoder=Transformer
# [2026-02-06 19:07:08] ==================================================================
# [2026-02-06 19:07:08] [Data] Initiating load for dataset: IMDB...
# [2026-02-06 19:07:08] [Data] Downloading/Loading TFDS: imdb_reviews...
# [2026-02-06 19:07:08] [Data] Extracting... (Train Limit: 10000, Test Limit: 10000)
# [2026-02-06 19:07:16] [Data] Loaded 10000 train, 10000 test samples.
# [2026-02-06 19:07:16] [Encoder] Constructing architecture: Transformer
# [2026-02-06 19:07:17] [Encoder] Model Built. Feature Output Shape: (None, 256)
# [2026-02-06 19:07:17] [Encoder] Starting ANN Pre-training (1 Epoch)...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 49s 145ms/step - accuracy: 0.6750 - loss: 0.5924
# [2026-02-06 19:08:05] [Encoder] ANN Training Complete. Time: 48.83s | Final Acc: 0.7371
# [2026-02-06 19:08:05] [Features] Generating Static Embeddings for SNN...
# [2026-02-06 19:08:32] [Features] Extraction Complete. Time: 26.00s
# [2026-02-06 19:08:32] [Features] Embedding Shape: (10000, 256)
# [2026-02-06 19:08:32] [SNN] Info: Running 1-SADP (Single Layer Supervised Plasticity)
# [2026-02-06 19:08:32] [SNN] Init 1-SADP Architecture. W1(Fixed):(256, 256), W2(Trainable):(256, 2)
# [2026-02-06 19:08:32] [SNN] Starting SNN Training Loop (25 Epochs)...
# [2026-02-06 19:08:34]   [Epoch 1/25] Acc: 0.5001 | Time: 2.71s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:08:37]   [Epoch 2/25] Acc: 0.4995 | Time: 2.75s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:08:42]   [Epoch 3/25] Acc: 0.4998 | Time: 4.94s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:08:45]   [Epoch 4/25] Acc: 0.5004 | Time: 2.73s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:08:48]   [Epoch 5/25] Acc: 0.4995 | Time: 2.74s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:08:51]   [Epoch 6/25] Acc: 0.5001 | Time: 2.79s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:08:56]   [Epoch 7/25] Acc: 0.5001 | Time: 4.81s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:08:59]   [Epoch 8/25] Acc: 0.4992 | Time: 2.74s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:02]   [Epoch 9/25] Acc: 0.4992 | Time: 2.84s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:05]   [Epoch 10/25] Acc: 0.5001 | Time: 3.06s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:09]   [Epoch 11/25] Acc: 0.5001 | Time: 4.19s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:12]   [Epoch 12/25] Acc: 0.5007 | Time: 2.82s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:15]   [Epoch 13/25] Acc: 0.4995 | Time: 2.82s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:20]   [Epoch 14/25] Acc: 0.4995 | Time: 4.78s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:23]   [Epoch 15/25] Acc: 0.4995 | Time: 2.75s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:26]   [Epoch 16/25] Acc: 0.4986 | Time: 2.84s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:29]   [Epoch 17/25] Acc: 0.5007 | Time: 2.79s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:34]   [Epoch 18/25] Acc: 0.4998 | Time: 4.78s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:37]   [Epoch 19/25] Acc: 0.5001 | Time: 2.80s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:39]   [Epoch 20/25] Acc: 0.5007 | Time: 2.78s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:42]   [Epoch 21/25] Acc: 0.4992 | Time: 2.83s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:47]   [Epoch 22/25] Acc: 0.4995 | Time: 4.78s | Energy (Sample): 5.00e-12 J
# [2026-02-06 19:09:50]   [Epoch 23/25] Acc: 0.5010 | Time: 2.79s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:53]   [Epoch 24/25] Acc: 0.4995 | Time: 2.76s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:56]   [Epoch 25/25] Acc: 0.4998 | Time: 2.72s | Energy (Sample): 0.00e+00 J
# [2026-02-06 19:09:56] [SNN] Training Complete.
#
# >>> RUNNING: Dataset=IMDB | Encoder=Word2Vec <<<
# [2026-02-06 19:09:56] ==================================================================
# [2026-02-06 19:09:56] STARTING PIPELINE: Dataset=imdb | Encoder=Word2Vec
# [2026-02-06 19:09:56] ==================================================================
# [2026-02-06 19:09:56] [Data] Initiating load for dataset: IMDB...
# [2026-02-06 19:09:56] [Data] Downloading/Loading TFDS: imdb_reviews...
# [2026-02-06 19:09:56] [Data] Extracting... (Train Limit: 10000, Test Limit: 10000)
# [2026-02-06 19:10:06] [Data] Loaded 10000 train, 10000 test samples.
# [2026-02-06 19:10:06] [Encoder] Constructing architecture: Word2Vec
# [2026-02-06 19:10:06] [Encoder] Loading Word2Vec (Direct Embedding)...
# [2026-02-06 19:10:17] [Encoder] Model Built. Feature Output Shape: (None, 256)
# [2026-02-06 19:10:17] [Encoder] Starting ANN Pre-training (1 Epoch)...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7203 - loss: 0.5556
# [2026-02-06 19:10:20] [Encoder] ANN Training Complete. Time: 3.34s | Final Acc: 0.7557
# [2026-02-06 19:10:20] [Features] Generating Static Embeddings for SNN...
# [2026-02-06 19:10:23] [Features] Extraction Complete. Time: 3.04s
# [2026-02-06 19:10:23] [Features] Embedding Shape: (10000, 256)
# [2026-02-06 19:10:23] [SNN] Info: Running 1-SADP (Single Layer Supervised Plasticity)
# [2026-02-06 19:10:23] [SNN] Init 1-SADP Architecture. W1(Fixed):(256, 256), W2(Trainable):(256, 2)
# [2026-02-06 19:10:23] [SNN] Starting SNN Training Loop (25 Epochs)...
# [2026-02-06 19:10:26]   [Epoch 1/25] Acc: 0.4998 | Time: 2.83s | Energy (Sample): 8.10e-10 J
# [2026-02-06 19:10:29]   [Epoch 2/25] Acc: 0.4998 | Time: 2.75s | Energy (Sample): 8.10e-10 J
# [2026-02-06 19:10:32]   [Epoch 3/25] Acc: 0.5001 | Time: 2.66s | Energy (Sample): 7.55e-10 J
# [2026-02-06 19:10:37]   [Epoch 4/25] Acc: 0.5007 | Time: 4.81s | Energy (Sample): 6.90e-10 J
# [2026-02-06 19:10:40]   [Epoch 5/25] Acc: 0.5007 | Time: 2.78s | Energy (Sample): 6.10e-10 J
# [2026-02-06 19:10:43]   [Epoch 6/25] Acc: 0.5004 | Time: 2.71s | Energy (Sample): 8.30e-10 J
# [2026-02-06 19:10:45]   [Epoch 7/25] Acc: 0.4989 | Time: 2.70s | Energy (Sample): 7.10e-10 J
# [2026-02-06 19:10:50]   [Epoch 8/25] Acc: 0.5004 | Time: 4.78s | Energy (Sample): 9.30e-10 J
# [2026-02-06 19:10:53]   [Epoch 9/25] Acc: 0.5004 | Time: 2.72s | Energy (Sample): 9.45e-10 J
# [2026-02-06 19:10:56]   [Epoch 10/25] Acc: 0.5010 | Time: 2.74s | Energy (Sample): 1.00e-09 J
# [2026-02-06 19:10:59]   [Epoch 11/25] Acc: 0.5001 | Time: 2.72s | Energy (Sample): 8.55e-10 J
# [2026-02-06 19:11:04]   [Epoch 12/25] Acc: 0.4989 | Time: 4.70s | Energy (Sample): 9.70e-10 J
# [2026-02-06 19:11:06]   [Epoch 13/25] Acc: 0.4998 | Time: 2.74s | Energy (Sample): 1.06e-09 J
# [2026-02-06 19:11:09]   [Epoch 14/25] Acc: 0.4998 | Time: 2.73s | Energy (Sample): 1.31e-09 J
# [2026-02-06 19:11:12]   [Epoch 15/25] Acc: 0.4998 | Time: 2.73s | Energy (Sample): 1.06e-09 J
# [2026-02-06 19:11:17]   [Epoch 16/25] Acc: 0.4992 | Time: 4.67s | Energy (Sample): 1.20e-09 J
# [2026-02-06 19:11:20]   [Epoch 17/25] Acc: 0.5001 | Time: 2.67s | Energy (Sample): 1.02e-09 J
# [2026-02-06 19:11:23]   [Epoch 18/25] Acc: 0.4995 | Time: 2.69s | Energy (Sample): 1.29e-09 J
# [2026-02-06 19:11:25]   [Epoch 19/25] Acc: 0.4989 | Time: 2.69s | Energy (Sample): 1.20e-09 J
# [2026-02-06 19:11:30]   [Epoch 20/25] Acc: 0.4983 | Time: 4.61s | Energy (Sample): 1.23e-09 J
# [2026-02-06 19:11:33]   [Epoch 21/25] Acc: 0.5003 | Time: 2.72s | Energy (Sample): 1.21e-09 J
# [2026-02-06 19:11:36]   [Epoch 22/25] Acc: 0.4996 | Time: 2.70s | Energy (Sample): 9.90e-10 J
# [2026-02-06 19:11:39]   [Epoch 23/25] Acc: 0.5002 | Time: 2.79s | Energy (Sample): 1.32e-09 J
# [2026-02-06 19:11:44]   [Epoch 24/25] Acc: 0.4995 | Time: 4.57s | Energy (Sample): 1.31e-09 J
# [2026-02-06 19:11:46]   [Epoch 25/25] Acc: 0.5004 | Time: 2.68s | Energy (Sample): 1.04e-09 J
# [2026-02-06 19:11:46] [SNN] Training Complete.
#
# >>> RUNNING: Dataset=IMDB | Encoder=USE <<<
# [2026-02-06 19:11:46] ==================================================================
# [2026-02-06 19:11:46] STARTING PIPELINE: Dataset=imdb | Encoder=USE
# [2026-02-06 19:11:46] ==================================================================
# [2026-02-06 19:11:46] [Data] Initiating load for dataset: IMDB...
# [2026-02-06 19:11:46] [Data] Downloading/Loading TFDS: imdb_reviews...
# [2026-02-06 19:11:46] [Data] Extracting... (Train Limit: 10000, Test Limit: 10000)
# [2026-02-06 19:11:55] [Data] Loaded 10000 train, 10000 test samples.
# [2026-02-06 19:11:55] [Encoder] Constructing architecture: USE
# [2026-02-06 19:11:55] [Encoder] Loading USE (Direct Embedding)...
# [2026-02-06 19:12:23] [Encoder] Model Built. Feature Output Shape: (None, 256)
# [2026-02-06 19:12:23] [Encoder] Starting ANN Pre-training (1 Epoch)...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.7939 - loss: 0.4694
# [2026-02-06 19:12:44] [Encoder] ANN Training Complete. Time: 21.58s | Final Acc: 0.8336
# [2026-02-06 19:12:44] [Features] Generating Static Embeddings for SNN...
# [2026-02-06 19:13:17] [Features] Extraction Complete. Time: 32.15s
# [2026-02-06 19:13:17] [Features] Embedding Shape: (10000, 256)
# [2026-02-06 19:13:17] [SNN] Info: Running 1-SADP (Single Layer Supervised Plasticity)
# [2026-02-06 19:13:17] [SNN] Init 1-SADP Architecture. W1(Fixed):(256, 256), W2(Trainable):(256, 2)
# [2026-02-06 19:13:17] [SNN] Starting SNN Training Loop (25 Epochs)...
# [2026-02-06 19:13:20]   [Epoch 1/25] Acc: 0.5385 | Time: 2.87s | Energy (Sample): 1.79e-08 J
# [2026-02-06 19:13:24]   [Epoch 2/25] Acc: 0.7463 | Time: 4.60s | Energy (Sample): 2.07e-08 J
# [2026-02-06 19:13:27]   [Epoch 3/25] Acc: 0.8038 | Time: 2.78s | Energy (Sample): 2.28e-08 J
# [2026-02-06 19:13:30]   [Epoch 4/25] Acc: 0.8259 | Time: 2.75s | Energy (Sample): 2.38e-08 J
# [2026-02-06 19:13:35]   [Epoch 5/25] Acc: 0.8191 | Time: 4.53s | Energy (Sample): 2.48e-08 J
# [2026-02-06 19:13:38]   [Epoch 6/25] Acc: 0.8210 | Time: 3.14s | Energy (Sample): 2.63e-08 J
# [2026-02-06 19:13:41]   [Epoch 7/25] Acc: 0.8149 | Time: 2.88s | Energy (Sample): 2.61e-08 J
# [2026-02-06 19:13:44]   [Epoch 8/25] Acc: 0.8147 | Time: 2.76s | Energy (Sample): 2.60e-08 J
# [2026-02-06 19:13:49]   [Epoch 9/25] Acc: 0.8109 | Time: 4.83s | Energy (Sample): 2.72e-08 J
# [2026-02-06 19:13:52]   [Epoch 10/25] Acc: 0.8038 | Time: 2.79s | Energy (Sample): 2.76e-08 J
# [2026-02-06 19:13:55]   [Epoch 11/25] Acc: 0.8073 | Time: 2.75s | Energy (Sample): 2.76e-08 J
# [2026-02-06 19:13:58]   [Epoch 12/25] Acc: 0.8093 | Time: 2.79s | Energy (Sample): 2.87e-08 J
# [2026-02-06 19:14:03]   [Epoch 13/25] Acc: 0.8039 | Time: 4.83s | Energy (Sample): 2.88e-08 J
# [2026-02-06 19:14:06]   [Epoch 14/25] Acc: 0.7964 | Time: 2.76s | Energy (Sample): 2.99e-08 J
# [2026-02-06 19:14:08]   [Epoch 15/25] Acc: 0.7956 | Time: 2.79s | Energy (Sample): 2.86e-08 J
# [2026-02-06 19:14:11]   [Epoch 16/25] Acc: 0.7987 | Time: 2.87s | Energy (Sample): 2.90e-08 J
# [2026-02-06 19:14:16]   [Epoch 17/25] Acc: 0.7926 | Time: 4.73s | Energy (Sample): 2.87e-08 J
# [2026-02-06 19:14:19]   [Epoch 18/25] Acc: 0.7910 | Time: 2.76s | Energy (Sample): 2.91e-08 J
# [2026-02-06 19:14:22]   [Epoch 19/25] Acc: 0.7921 | Time: 2.87s | Energy (Sample): 2.95e-08 J
# [2026-02-06 19:14:26]   [Epoch 20/25] Acc: 0.8016 | Time: 3.13s | Energy (Sample): 2.83e-08 J
# [2026-02-06 19:14:30]   [Epoch 21/25] Acc: 0.8001 | Time: 4.22s | Energy (Sample): 2.80e-08 J
# [2026-02-06 19:14:33]   [Epoch 22/25] Acc: 0.7914 | Time: 2.88s | Energy (Sample): 3.01e-08 J
# [2026-02-06 19:14:36]   [Epoch 23/25] Acc: 0.7862 | Time: 2.83s | Energy (Sample): 2.96e-08 J
# [2026-02-06 19:14:41]   [Epoch 24/25] Acc: 0.7858 | Time: 5.02s | Energy (Sample): 2.96e-08 J
# [2026-02-06 19:14:44]   [Epoch 25/25] Acc: 0.7821 | Time: 2.78s | Energy (Sample): 2.97e-08 J
# [2026-02-06 19:14:44] [SNN] Training Complete.
#
# >>> RUNNING: Dataset=IMDB | Encoder=BERT <<<
# [2026-02-06 19:14:44] ==================================================================
# [2026-02-06 19:14:44] STARTING PIPELINE: Dataset=imdb | Encoder=BERT
# [2026-02-06 19:14:44] ==================================================================
# [2026-02-06 19:14:44] [Data] Initiating load for dataset: IMDB...
# [2026-02-06 19:14:44] [Data] Downloading/Loading TFDS: imdb_reviews...
# [2026-02-06 19:14:44] [Data] Extracting... (Train Limit: 10000, Test Limit: 10000)
# [2026-02-06 19:14:52] [Data] Loaded 10000 train, 10000 test samples.
# [2026-02-06 19:14:52] [Encoder] Constructing architecture: BERT
# [2026-02-06 19:14:52] [Encoder] Loading BERT (Transformer-style)...
# [2026-02-06 19:15:14] [Encoder] Model Built. Feature Output Shape: (None, 256)
# [2026-02-06 19:15:14] [Encoder] Starting ANN Pre-training (1 Epoch)...
#  83/313 ━━━━━━━━━━━━━━━━━━━━ 55:23 14s/step - accuracy: 0.5613 - loss: 0.7927
